# %% [markdown]
# Introduction:
# This data ceased updating with the transition to a new records management system on 11/14/2023. Access to the updated data source will be provided in the future.

# %%
import pandas as pd
df = pd.read_csv("Non_Traffic.csv")
df.head(20)
# Out:
#     _id       PK       CCR GENDER RACE   AGE            CITEDTIME  \
# 0     1  1078081  16157849      M    B  29.0  2016-08-22T23:45:00
# 1     2  1078082  16157849      M    W  21.0  2016-08-22T23:45:00
# 2     3  1078083  16159579    NaN  NaN   NaN  2016-08-25T11:10:00
# 3     4  1078084  16159780      M    B  22.0  2016-08-25T16:42:00
# 4     5  1078085  16161591      F    W  22.0  2016-08-28T00:58:00
# 5     6  1078086  16162400      M    W  28.0  2016-08-29T10:34:00
# 6     7  1078087  16162524      M    B  56.0  2016-08-29T13:00:00
# 7     8  1078088  16162524      M    W  44.0  2016-08-29T13:00:00
# 8     9  1078089  16083638      M    W  50.0  2016-05-07T16:30:00
# 9    10  1078090  16077700      M    B  24.0  2016-04-29T01:05:00
# 10   11  1078091  16077700      M    B  24.0  2016-04-29T01:05:00
# 11   12  1078092  16078368      M    W  22.0  2016-04-30T02:01:00
# 12   13  1078093  16083547      M    B  31.0  2016-05-07T13:50:00
# ...

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("Non_Traffic.csv")

# Filter to show only the NEIGHBORHOOD and COUNCIL_DISTRICT columns
filtered_df = df[['NEIGHBORHOOD', 'COUNCIL_DISTRICT']]

# Drop rows with missing council district BEFORE showing the top 10
filtered_df = filtered_df.dropna(subset=['COUNCIL_DISTRICT'])

# Now show the first 10 rows (all will have valid council district values)
# Get first 10 unique neighborhoods
unique_df = filtered_df.drop_duplicates(subset='NEIGHBORHOOD').head(10)
print(unique_df)
# Out:
#                    NEIGHBORHOOD  COUNCIL_DISTRICT
# 0                 North Oakland               8.0
# 3                Homewood South               9.0
# 4           Upper Lawrenceville               7.0
# 5   Golden Triangle/Civic Arena               6.0
# 8           Lower Lawrenceville               7.0
# 9              South Side Flats               3.0
# 12                 East Liberty               9.0
# 14                 Point Breeze               9.0
# 17              Central Oakland               3.0
# 22                    Brookline               4.0

# %%
# Drop rows with missing council district
filtered_df = filtered_df.dropna(subset=['COUNCIL_DISTRICT'])

# Get 10 unique neighborhoods directly (this avoids duplicates after selection)
plot_df = filtered_df.drop_duplicates(subset='NEIGHBORHOOD', keep='first').head(10)

# %%
# Plot
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 7))
barplot = sns.barplot(data=plot_df, x='NEIGHBORHOOD', y='COUNCIL_DISTRICT')

# Fix: Use enumerate so label positions match bars
for i, (neighborhood, row) in enumerate(plot_df.iterrows()):
    barplot.text(i, row['COUNCIL_DISTRICT'] + 0.1, str(int(row['COUNCIL_DISTRICT'])),
                 color='black', ha="center", fontsize=10)

plt.title('Council District of 10 Neighborhoods', fontsize=16)
plt.xlabel('Neighborhood', fontsize=12)
plt.ylabel('Council District', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Introduction**
# Introduction: Introduce the project, and your approach, talk about the process of how you came up with the metric and some alternatives you may have explored.
#
#
# **The Metric: Describe your metric, and what features are you measuring.**
# My metric is based on the neighborhood with the most non traffic citation. I am measuring community behaviour and safety through the number of citations based on littering, harrasment, and theft. Neighbhorhood with fewer citation suggest better community behavior.
#
# **What datasets are you using?**
# I am using the City of Pittsburgh Non-Traffic Citations dataset, provided by the Department of Innovation & Performance.
#
# **The Best Neighborhood: Apply the metric from the previous section to determine the best neighborhood in Pittsburgh. Beyond just executing code, provide a narrative about why you think this is the best neighborhood. Incorporate a data visualization, perhaps to rank all of the neighborhoods or show a neighborhood’s best-ness over time. The key is to make a data driven argument.**
# According to our analysis, and based on our citation counts, squirrel Hills south has the fewest total non-traffic citations.
#
# **Conclusion: Reflect on how the data-driven determination of “best neighborhood” is the same or different from your personal favorite neighborhood. Each member of the group should write their own response to this.**
# I personally like Central Oakland because it is a student friendly with easy accessibility to food and transit. And based on data, it has one of the lowest non traffic citaition and it shows that checking stats can be helpful.
